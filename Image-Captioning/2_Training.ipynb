# %% [markdown]
# # Computer Vision Nanodegree
#
# ## Project: Image Captioning
#
# ---
#
# In this notebook, you will train your CNN-RNN model.
#
# You are welcome and encouraged to try out many different architectures and hyperparameters when searching for a good model.
#
# This does have the potential to make the project quite messy!  Before submitting your project, make sure that you clean up:
# - the code you write in this notebook.  The notebook should describe how to train a single CNN-RNN architecture, corresponding to your final choice of hyperparameters.  You should structure the notebook so that the reviewer can replicate your results by running the code in this notebook.
# - the output of the code cell in **Step 2**.  The output should show the output obtained when training the model from scratch.
#
# This notebook **will be graded**.
#
# Feel free to use the links below to navigate the notebook:
# - [Step 1](#step1): Training Setup
# - [Step 2](#step2): Train your Model
# - [Step 3](#step3): (Optional) Validate your Model

# %% [markdown]
# <a id='step1'></a>
# ## Step 1: Training Setup
#
# In this step of the notebook, you will customize the training of your CNN-RNN model by specifying hyperparameters and setting other options that are important to the training procedure.  The values you set now will be used when training your model in **Step 2** below.
#
# You should only amend blocks of code that are preceded by a `TODO` statement.  **Any code blocks that are not preceded by a `TODO` statement should not be modified**.
#
# ### Task #1
#
# Begin by setting the following variables:
# - `batch_size` - the batch size of each training batch.  It is the number of image-caption pairs used to amend the model weights in each training step.
# - `vocab_threshold` - the minimum word count threshold.  Note that a larger threshold will result in a smaller vocabulary, whereas a smaller threshold will include rarer words and result in a larger vocabulary.
# - `vocab_from_file` - a Boolean that decides whether to load the vocabulary from file.
# - `embed_size` - the dimensionality of the image and word embeddings.
# - `hidden_size` - the number of features in the hidden state of the RNN decoder.
# - `num_epochs` - the number of epochs to train the model.  We recommend that you set `num_epochs=3`, but feel free to increase or decrease this number as you wish.  [This paper](https://arxiv.org/pdf/1502.03044.pdf) trained a captioning model on a single state-of-the-art GPU for 3 days, but you'll soon see that you can get reasonable results in a matter of a few hours!  (_But of course, if you want your model to compete with current research, you will have to train for much longer._)
# - `save_every` - determines how often to save the model weights.  We recommend that you set `save_every=1`, to save the model weights after each epoch.  This way, after the `i`th epoch, the encoder and decoder weights will be saved in the `models/` folder as `encoder-i.pkl` and `decoder-i.pkl`, respectively.
# - `print_every` - determines how often to print the batch loss to the Jupyter notebook while training.  Note that you **will not** observe a monotonic decrease in the loss function while training - this is perfectly fine and completely expected!  You are encouraged to keep this at its default value of `100` to avoid clogging the notebook, but feel free to change it.
# - `log_file` - the name of the text file containing - for every step - how the loss and perplexity evolved during training.
#
# If you're not sure where to begin to set some of the values above, you can peruse [this paper](https://arxiv.org/pdf/1502.03044.pdf) and [this paper](https://arxiv.org/pdf/1411.4555.pdf) for useful guidance!  **To avoid spending too long on this notebook**, you are encouraged to consult these suggested research papers to obtain a strong initial guess for which hyperparameters are likely to work best.  Then, train a single model, and proceed to the next notebook (**3_Inference.ipynb**).  If you are unhappy with your performance, you can return to this notebook to tweak the hyperparameters (and/or the architecture in **model.py**) and re-train your model.
#
# ### Question 1
#
# **Question:** Describe your CNN-RNN architecture in detail.  With this architecture in mind, how did you select the values of the variables in Task 1?  If you consulted a research paper detailing a successful implementation of an image captioning model, please provide the reference.
#
# **Answer:** The architecture consists of an encoder and a decoder. The encoder utilizes the pre-trained Resnet network, followed by an embedding step with an embed size of 300. The features are then passed to the decoder which consists of an embedding layer, an lstm layer and a linear layer. The variables were selected by following the recommnedations outlines in the two papers in the  preceding cells.
#
#
# ### (Optional) Task #2
#
# Note that we have provided a recommended image transform `transform_train` for pre-processing the training images, but you are welcome (and encouraged!) to modify it as you wish.  When modifying this transform, keep in mind that:
# - the images in the dataset have varying heights and widths, and
# - if using a pre-trained model, you must perform the corresponding appropriate normalization.
#
# ### Question 2
#
# **Question:** How did you select the transform in `transform_train`?  If you left the transform at its provided value, why do you think that it is a good choice for your CNN architecture?
#
# **Answer:** I left the transform at the provided values because these result in a random crop, a random flipping of the image, a transfer to tensor and then nromalization according to the pre-trained model.
#
# ### Task #3
#
# Next, you will specify a Python list containing the learnable parameters of the model.  For instance, if you decide to make all weights in the decoder trainable, but only want to train the weights in the embedding layer of the encoder, then you should set `params` to something like:
# ```
# params = list(decoder.parameters()) + list(encoder.embed.parameters())
# ```
#
# ### Question 3
#
# **Question:** How did you select the trainable parameters of your architecture?  Why do you think this is a good choice?
#
# **Answer:** I followed the recommendations in the above task statement as this provides the model with a reasonable amount of trainability without adding unecessary complexity to the model.
#
# ### Task #4
#
# Finally, you will select an [optimizer](http://pytorch.org/docs/master/optim.html#torch.optim.Optimizer).
#
# ### Question 4
#
# **Question:** How did you select the optimizer used to train your model?
#
# **Answer:** Initially, I experimented with SGD optimizer but was getting unsatisfactory results and so swtiched the the Adam optimizer with support from my Mentor.

# %%
import torch
import torch.nn as nn
from torchvision import transforms
import sys
sys.path.append('/opt/cocoapi/PythonAPI')
from pycocotools.coco import COCO
from data_loader import get_loader
from model import EncoderCNN, DecoderRNN
import math
import torch.optim as optim
import nltk
nltk.download('punkt')



## TODO #1: Select appropriate values for the Python variables below.
batch_size = 64         # batch size
vocab_threshold = 4        # minimum word count threshold
vocab_from_file = False    # if True, load existing vocab file
embed_size = 300           # dimensionality of image and word embeddings
hidden_size = 512          # number of features in hidden state of the RNN decoder
num_epochs = 3             # number of training epochs
save_every = 1             # determines frequency of saving model weights
print_every = 100          # determines window for printing average loss
log_file = 'training_log.txt'       # name of file with saved training loss and perplexity

# (Optional) TODO #2: Amend the image transform below.
transform_train = transforms.Compose([ 
    transforms.Resize(256),                          # smaller edge of image resized to 256
    transforms.RandomCrop(224),                      # get 224x224 crop from random location
    transforms.RandomHorizontalFlip(),               # horizontally flip image with probability=0.5
    transforms.ToTensor(),                           # convert the PIL Image to a tensor
    transforms.Normalize((0.485, 0.456, 0.406),      # normalize image for pre-trained model
                         (0.229, 0.224, 0.225))])


# Build data loader.
data_loader = get_loader(transform=transform_train,
                         mode='train',
                         batch_size=batch_size,
                         vocab_threshold=vocab_threshold,
                         vocab_from_file=vocab_from_file)
                         

# The size of the vocabulary.
vocab_size = len(data_loader.dataset.vocab)

# Initialize the encoder and decoder. 
encoder = EncoderCNN(embed_size)
decoder = DecoderRNN(embed_size, hidden_size, vocab_size)

# Move models to GPU if CUDA is available. 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
encoder.to(device)
decoder.to(device)

# Define the loss function. 
criterion = nn.CrossEntropyLoss().cuda() if torch.cuda.is_available() else nn.CrossEntropyLoss()

# TODO #3: Specify the learnable parameters of the model.
params = list(decoder.parameters()) + list(encoder.embed.parameters())

# TODO #4: Define the optimizer.
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(params, lr=0.001, betas=(0.9,0.999))

# Set the total number of training steps per epoch.
total_step = math.ceil(len(data_loader.dataset.caption_lengths) / data_loader.batch_sampler.batch_size)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# loading annotations into memory...
# Done (t=1.03s)
# creating index...
# index created!
# [0/414113] Tokenizing captions...
# [100000/414113] Tokenizing captions...
# [200000/414113] Tokenizing captions...
# [300000/414113] Tokenizing captions...
# [400000/414113] Tokenizing captions...
# loading annotations into memory...
# Done (t=0.95s)
# creating index...
#   0%|          | 436/414113 [00:00<01:34, 4356.59it/s]
# index created!
# Obtaining caption lengths...
# 100%|██████████| 414113/414113 [01:34<00:00, 4378.66it/s]
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.torch/models/resnet50-19c8e357.pth
# 100%|██████████| 102502400/102502400 [00:01<00:00, 60619038.76it/s]

# %% [markdown]
# <a id='step2'></a>
# ## Step 2: Train your Model
#
# Once you have executed the code cell in **Step 1**, the training procedure below should run without issue.
#
# It is completely fine to leave the code cell below as-is without modifications to train your model.  However, if you would like to modify the code used to train the model below, you must ensure that your changes are easily parsed by your reviewer.  In other words, make sure to provide appropriate comments to describe how your code works!
#
# You may find it useful to load saved weights to resume training.  In that case, note the names of the files containing the encoder and decoder weights that you'd like to load (`encoder_file` and `decoder_file`).  Then you can load the weights by using the lines below:
#
# ```python
# # Load pre-trained weights before resuming training.
# encoder.load_state_dict(torch.load(os.path.join('./models', encoder_file)))
# decoder.load_state_dict(torch.load(os.path.join('./models', decoder_file)))
# ```
#
# While trying out parameters, make sure to take extensive notes and record the settings that you used in your various training runs.  In particular, you don't want to encounter a situation where you've trained a model for several hours but can't remember what settings you used :).
#
# ### A Note on Tuning Hyperparameters
#
# To figure out how well your model is doing, you can look at how the training loss and perplexity evolve during training - and for the purposes of this project, you are encouraged to amend the hyperparameters based on this information.
#
# However, this will not tell you if your model is overfitting to the training data, and, unfortunately, overfitting is a problem that is commonly encountered when training image captioning models.
#
# For this project, you need not worry about overfitting. **This project does not have strict requirements regarding the performance of your model**, and you just need to demonstrate that your model has learned **_something_** when you generate captions on the test data.  For now, we strongly encourage you to train your model for the suggested 3 epochs without worrying about performance; then, you should immediately transition to the next notebook in the sequence (**3_Inference.ipynb**) to see how your model performs on the test data.  If your model needs to be changed, you can come back to this notebook, amend hyperparameters (if necessary), and re-train the model.
#
# That said, if you would like to go above and beyond in this project, you can read about some approaches to minimizing overfitting in section 4.3.1 of [this paper](http://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=7505636).  In the next (optional) step of this notebook, we provide some guidance for assessing the performance on the validation dataset.

# %%
import torch.utils.data as data
import numpy as np
import os
import requests
import time
from workspace_utils import active_session

with active_session():

    # Open the training log file.
    f = open(log_file, 'w')

    old_time = time.time()
    response = requests.request("GET", 
                                "http://metadata.google.internal/computeMetadata/v1/instance/attributes/keep_alive_token", 
                                headers={"Metadata-Flavor":"Google"})
    
    #encoder.load_state_dict(torch.load(os.path.join('./models', encoder_file)))
    #decoder.load_state_dict(torch.load(os.path.join('./models', decoder_file)))

    for epoch in range(1, num_epochs+1):

        for i_step in range(1, total_step+1):

            if time.time() - old_time > 60:
                old_time = time.time()
                requests.request("POST", 
                                 "https://nebula.udacity.com/api/v1/remote/keep-alive", 
                                 headers={'Authorization': "STAR " + response.text})

            # Randomly sample a caption length, and sample indices with that length.
            indices = data_loader.dataset.get_train_indices()
            # Create and assign a batch sampler to retrieve a batch with the sampled indices.
            new_sampler = data.sampler.SubsetRandomSampler(indices=indices)
            data_loader.batch_sampler.sampler = new_sampler

            # Obtain the batch.
            images, captions = next(iter(data_loader))

            # Move batch of images and captions to GPU if CUDA is available.
            images = images.to(device)
            captions = captions.to(device)

            # Zero the gradients.
            decoder.zero_grad()
            encoder.zero_grad()

            # Pass the inputs through the CNN-RNN model.
            features = encoder(images)
            outputs = decoder(features, captions)

            # Calculate the batch loss.
            loss = criterion(outputs.view(-1, vocab_size), captions.view(-1))

            # Backward pass.
            loss.backward()

            # Update the parameters in the optimizer.
            optimizer.step()

            # Get training statistics.
            stats = 'Epoch [%d/%d], Step [%d/%d], Loss: %.4f, Perplexity: %5.4f' % (epoch, num_epochs, i_step, total_step, loss.item(), np.exp(loss.item()))

            # Print training statistics (on same line).
            print('\r' + stats, end="")
            sys.stdout.flush()

            # Print training statistics to file.
            f.write(stats + '\n')
            f.flush()

            # Print training statistics (on different line).
            if i_step % print_every == 0:
                print('\r' + stats)

        # Save the weights.
        if epoch % save_every == 0:
            torch.save(decoder.state_dict(), os.path.join('./models', 'decoder-%d.pkl' % epoch))
            torch.save(encoder.state_dict(), os.path.join('./models', 'encoder-%d.pkl' % epoch))

    # Close the training log file.
    f.close()
# Out:
# Epoch [1/3], Step [100/6471], Loss: 4.1518, Perplexity: 63.55005
# Epoch [1/3], Step [200/6471], Loss: 3.7527, Perplexity: 42.63576
# Epoch [1/3], Step [300/6471], Loss: 3.4262, Perplexity: 30.7588
# Epoch [1/3], Step [400/6471], Loss: 3.2799, Perplexity: 26.5736
# Epoch [1/3], Step [500/6471], Loss: 3.1634, Perplexity: 23.6502
# Epoch [1/3], Step [600/6471], Loss: 3.3402, Perplexity: 28.22450
# Epoch [1/3], Step [700/6471], Loss: 3.0534, Perplexity: 21.1883
# Epoch [1/3], Step [800/6471], Loss: 2.9829, Perplexity: 19.7455
# Epoch [1/3], Step [900/6471], Loss: 2.6204, Perplexity: 13.7418
# Epoch [1/3], Step [1000/6471], Loss: 2.7396, Perplexity: 15.4801
# Epoch [1/3], Step [1100/6471], Loss: 2.6456, Perplexity: 14.0922
# Epoch [1/3], Step [1200/6471], Loss: 2.6126, Perplexity: 13.6347
# Epoch [1/3], Step [1300/6471], Loss: 2.5853, Perplexity: 13.2679
# Epoch [1/3], Step [1500/6471], Loss: 2.5234, Perplexity: 12.4703
# Epoch [1/3], Step [1600/6471], Loss: 2.2027, Perplexity: 9.04969
# Epoch [1/3], Step [1700/6471], Loss: 2.7095, Perplexity: 15.02191
# Epoch [1/3], Step [1800/6471], Loss: 2.7825, Perplexity: 16.1592
# Epoch [1/3], Step [1900/6471], Loss: 2.3513, Perplexity: 10.4989
# Epoch [1/3], Step [2000/6471], Loss: 2.4522, Perplexity: 11.6144
# Epoch [1/3], Step [2100/6471], Loss: 2.3901, Perplexity: 10.9150
# Epoch [1/3], Step [2200/6471], Loss: 2.9318, Perplexity: 18.7605
# Epoch [1/3], Step [2300/6471], Loss: 2.7927, Perplexity: 16.3244
# Epoch [1/3], Step [2400/6471], Loss: 2.4048, Perplexity: 11.0763
# Epoch [1/3], Step [2500/6471], Loss: 2.5669, Perplexity: 13.0252
# Epoch [1/3], Step [2600/6471], Loss: 2.3117, Perplexity: 10.0915
# Epoch [1/3], Step [2700/6471], Loss: 2.3429, Perplexity: 10.4111
# Epoch [1/3], Step [2800/6471], Loss: 2.2640, Perplexity: 9.62152
# Epoch [1/3], Step [2900/6471], Loss: 2.3090, Perplexity: 10.0639
# Epoch [1/3], Step [3000/6471], Loss: 2.3378, Perplexity: 10.3579
# Epoch [1/3], Step [3100/6471], Loss: 2.2948, Perplexity: 9.92283
# Epoch [1/3], Step [3200/6471], Loss: 2.6831, Perplexity: 14.6309
# Epoch [1/3], Step [3300/6471], Loss: 2.3791, Perplexity: 10.7954
# Epoch [1/3], Step [3400/6471], Loss: 2.2047, Perplexity: 9.06754
# Epoch [1/3], Step [3500/6471], Loss: 2.7653, Perplexity: 15.8835
# Epoch [1/3], Step [3600/6471], Loss: 2.4012, Perplexity: 11.0365
# Epoch [1/3], Step [3700/6471], Loss: 2.4857, Perplexity: 12.0099
# Epoch [1/3], Step [3800/6471], Loss: 2.1931, Perplexity: 8.96262
# Epoch [1/3], Step [3900/6471], Loss: 2.0814, Perplexity: 8.01551
# Epoch [1/3], Step [4000/6471], Loss: 2.2696, Perplexity: 9.67562
# Epoch [1/3], Step [4100/6471], Loss: 2.2295, Perplexity: 9.29562
# Epoch [1/3], Step [4200/6471], Loss: 2.0610, Perplexity: 7.85372
# Epoch [1/3], Step [4300/6471], Loss: 2.3865, Perplexity: 10.8750
# Epoch [1/3], Step [4400/6471], Loss: 2.3396, Perplexity: 10.3775
# Epoch [1/3], Step [4500/6471], Loss: 2.3516, Perplexity: 10.5021
# Epoch [1/3], Step [4600/6471], Loss: 2.2349, Perplexity: 9.34549
# Epoch [1/3], Step [4700/6471], Loss: 2.2102, Perplexity: 9.11780
# Epoch [1/3], Step [4900/6471], Loss: 2.6493, Perplexity: 14.1446
# Epoch [1/3], Step [5000/6471], Loss: 2.2616, Perplexity: 9.59874
# Epoch [1/3], Step [5100/6471], Loss: 2.5355, Perplexity: 12.6229
# Epoch [1/3], Step [5200/6471], Loss: 2.2713, Perplexity: 9.69199
# Epoch [1/3], Step [5300/6471], Loss: 2.2966, Perplexity: 9.94071
# Epoch [1/3], Step [5400/6471], Loss: 2.1312, Perplexity: 8.42479
# Epoch [1/3], Step [5500/6471], Loss: 2.1107, Perplexity: 8.25419
# Epoch [1/3], Step [5600/6471], Loss: 2.3558, Perplexity: 10.5461
# Epoch [1/3], Step [5700/6471], Loss: 2.1445, Perplexity: 8.53805
# Epoch [1/3], Step [5800/6471], Loss: 2.3751, Perplexity: 10.7517
# Epoch [1/3], Step [5900/6471], Loss: 2.3966, Perplexity: 10.9861
# Epoch [1/3], Step [6000/6471], Loss: 2.0351, Perplexity: 7.65303
# Epoch [1/3], Step [6100/6471], Loss: 2.0274, Perplexity: 7.59405
# Epoch [1/3], Step [6200/6471], Loss: 1.9734, Perplexity: 7.19504
# Epoch [1/3], Step [6300/6471], Loss: 2.0410, Perplexity: 7.69819
# Epoch [1/3], Step [6400/6471], Loss: 2.2916, Perplexity: 9.89118
# Epoch [2/3], Step [100/6471], Loss: 2.0914, Perplexity: 8.095996
# Epoch [2/3], Step [200/6471], Loss: 2.0977, Perplexity: 8.14753
# Epoch [2/3], Step [300/6471], Loss: 2.3955, Perplexity: 10.9733
# Epoch [2/3], Step [400/6471], Loss: 2.5059, Perplexity: 12.2542
# Epoch [2/3], Step [500/6471], Loss: 2.3825, Perplexity: 10.8322
# Epoch [2/3], Step [600/6471], Loss: 1.9547, Perplexity: 7.06203
# Epoch [2/3], Step [700/6471], Loss: 2.2437, Perplexity: 9.42784
# Epoch [2/3], Step [800/6471], Loss: 2.1121, Perplexity: 8.26553
# Epoch [2/3], Step [900/6471], Loss: 2.1951, Perplexity: 8.98053
# Epoch [2/3], Step [1000/6471], Loss: 2.2962, Perplexity: 9.9359
# Epoch [2/3], Step [1100/6471], Loss: 1.9979, Perplexity: 7.37334
# Epoch [2/3], Step [1200/6471], Loss: 2.0361, Perplexity: 7.66088
# Epoch [2/3], Step [1300/6471], Loss: 2.7265, Perplexity: 15.2789
# Epoch [2/3], Step [1500/6471], Loss: 2.0317, Perplexity: 7.627261
# Epoch [2/3], Step [1600/6471], Loss: 2.2140, Perplexity: 9.15221
# Epoch [2/3], Step [1700/6471], Loss: 2.0640, Perplexity: 7.87726
# Epoch [2/3], Step [1800/6471], Loss: 1.9926, Perplexity: 7.33471
# Epoch [2/3], Step [1900/6471], Loss: 1.9924, Perplexity: 7.33344
# Epoch [2/3], Step [2000/6471], Loss: 2.2466, Perplexity: 9.45572
# Epoch [2/3], Step [2100/6471], Loss: 2.1473, Perplexity: 8.56196
# Epoch [2/3], Step [2200/6471], Loss: 1.9327, Perplexity: 6.90795
# Epoch [2/3], Step [2300/6471], Loss: 2.1631, Perplexity: 8.69780
# Epoch [2/3], Step [2400/6471], Loss: 2.0105, Perplexity: 7.46719
# Epoch [2/3], Step [2500/6471], Loss: 2.1701, Perplexity: 8.75957
# Epoch [2/3], Step [2600/6471], Loss: 1.9863, Perplexity: 7.28846
# Epoch [2/3], Step [2700/6471], Loss: 2.0501, Perplexity: 7.76879
# Epoch [2/3], Step [2800/6471], Loss: 2.0374, Perplexity: 7.67088
# Epoch [2/3], Step [2900/6471], Loss: 2.1436, Perplexity: 8.53013
# Epoch [2/3], Step [3000/6471], Loss: 2.1191, Perplexity: 8.32406
# Epoch [2/3], Step [3100/6471], Loss: 2.0901, Perplexity: 8.08581
# Epoch [2/3], Step [3200/6471], Loss: 2.0374, Perplexity: 7.67108
# Epoch [2/3], Step [3300/6471], Loss: 2.3455, Perplexity: 10.4384
# Epoch [2/3], Step [3400/6471], Loss: 2.2888, Perplexity: 9.86335
# Epoch [2/3], Step [3500/6471], Loss: 2.1357, Perplexity: 8.46290
# Epoch [2/3], Step [3600/6471], Loss: 1.9493, Perplexity: 7.02352
# Epoch [2/3], Step [3700/6471], Loss: 2.4804, Perplexity: 11.9463
# Epoch [2/3], Step [3800/6471], Loss: 2.4652, Perplexity: 11.7657
# Epoch [2/3], Step [3900/6471], Loss: 1.9459, Perplexity: 7.00013
# Epoch [2/3], Step [4000/6471], Loss: 2.3323, Perplexity: 10.3011
# Epoch [2/3], Step [4100/6471], Loss: 2.0760, Perplexity: 7.97295
# Epoch [2/3], Step [4200/6471], Loss: 2.0236, Perplexity: 7.56546
# Epoch [2/3], Step [4300/6471], Loss: 1.9732, Perplexity: 7.19373
# Epoch [2/3], Step [4400/6471], Loss: 2.2022, Perplexity: 9.04495
# Epoch [2/3], Step [4500/6471], Loss: 2.2046, Perplexity: 9.06664
# Epoch [2/3], Step [4600/6471], Loss: 2.0098, Perplexity: 7.46167
# Epoch [2/3], Step [4700/6471], Loss: 2.6624, Perplexity: 14.3303
# Epoch [2/3], Step [4800/6471], Loss: 1.9960, Perplexity: 7.35959
# Epoch [2/3], Step [4900/6471], Loss: 1.9784, Perplexity: 7.23116
# Epoch [2/3], Step [5000/6471], Loss: 2.0613, Perplexity: 7.85619
# Epoch [2/3], Step [5100/6471], Loss: 2.1661, Perplexity: 8.72386
# Epoch [2/3], Step [5200/6471], Loss: 2.3371, Perplexity: 10.3507
# Epoch [2/3], Step [5300/6471], Loss: 2.0807, Perplexity: 8.00999
# Epoch [2/3], Step [5400/6471], Loss: 1.9783, Perplexity: 7.23018
# Epoch [2/3], Step [5500/6471], Loss: 1.9725, Perplexity: 7.18855
# Epoch [2/3], Step [5600/6471], Loss: 2.0974, Perplexity: 8.14484
# Epoch [2/3], Step [5700/6471], Loss: 1.7648, Perplexity: 5.84017
# Epoch [2/3], Step [5800/6471], Loss: 2.0910, Perplexity: 8.09343
# Epoch [2/3], Step [5900/6471], Loss: 1.8389, Perplexity: 6.28974
# Epoch [2/3], Step [6000/6471], Loss: 2.0235, Perplexity: 7.56484
# Epoch [2/3], Step [6100/6471], Loss: 2.2036, Perplexity: 9.05784
# Epoch [2/3], Step [6200/6471], Loss: 1.8140, Perplexity: 6.13512
# Epoch [2/3], Step [6300/6471], Loss: 2.1198, Perplexity: 8.32947
# Epoch [2/3], Step [6400/6471], Loss: 1.9637, Perplexity: 7.12555
# Epoch [3/3], Step [100/6471], Loss: 1.9953, Perplexity: 7.354553
# Epoch [3/3], Step [200/6471], Loss: 1.9188, Perplexity: 6.81315
# Epoch [3/3], Step [300/6471], Loss: 1.9553, Perplexity: 7.06582
# Epoch [3/3], Step [400/6471], Loss: 1.9150, Perplexity: 6.78712
# Epoch [3/3], Step [500/6471], Loss: 2.4623, Perplexity: 11.7314
# Epoch [3/3], Step [600/6471], Loss: 2.1513, Perplexity: 8.59639
# Epoch [3/3], Step [700/6471], Loss: 1.8059, Perplexity: 6.08568
# Epoch [3/3], Step [800/6471], Loss: 2.2073, Perplexity: 9.09140
# Epoch [3/3], Step [900/6471], Loss: 1.8486, Perplexity: 6.35118
# Epoch [3/3], Step [1000/6471], Loss: 1.9429, Perplexity: 6.9793
# Epoch [3/3], Step [1100/6471], Loss: 1.9941, Perplexity: 7.34563
# Epoch [3/3], Step [1200/6471], Loss: 2.0652, Perplexity: 7.88701
# Epoch [3/3], Step [1300/6471], Loss: 2.2767, Perplexity: 9.74405
# Epoch [3/3], Step [1400/6471], Loss: 2.6148, Perplexity: 13.6646
# Epoch [3/3], Step [1500/6471], Loss: 1.9049, Perplexity: 6.71884
# Epoch [3/3], Step [1600/6471], Loss: 1.9898, Perplexity: 7.31381
# Epoch [3/3], Step [1700/6471], Loss: 1.9283, Perplexity: 6.87824
# Epoch [3/3], Step [1800/6471], Loss: 1.9847, Perplexity: 7.27666
# Epoch [3/3], Step [1900/6471], Loss: 1.8095, Perplexity: 6.10731
# Epoch [3/3], Step [2000/6471], Loss: 1.7794, Perplexity: 5.92668
# Epoch [3/3], Step [2100/6471], Loss: 1.9897, Perplexity: 7.31334
# Epoch [3/3], Step [2200/6471], Loss: 1.8817, Perplexity: 6.56497
# Epoch [3/3], Step [2300/6471], Loss: 1.9996, Perplexity: 7.38616
# Epoch [3/3], Step [2400/6471], Loss: 1.8902, Perplexity: 6.62073
# Epoch [3/3], Step [2500/6471], Loss: 2.6846, Perplexity: 14.6528
# Epoch [3/3], Step [2600/6471], Loss: 1.8365, Perplexity: 6.27488
# Epoch [3/3], Step [2700/6471], Loss: 2.0976, Perplexity: 8.14650
# Epoch [3/3], Step [2800/6471], Loss: 2.1822, Perplexity: 8.86572
# Epoch [3/3], Step [2900/6471], Loss: 2.4598, Perplexity: 11.7025
# Epoch [3/3], Step [3000/6471], Loss: 1.9002, Perplexity: 6.68702
# Epoch [3/3], Step [3100/6471], Loss: 1.8498, Perplexity: 6.358444
# Epoch [3/3], Step [3200/6471], Loss: 1.9698, Perplexity: 7.16907
# Epoch [3/3], Step [3300/6471], Loss: 1.9973, Perplexity: 7.36930
# Epoch [3/3], Step [3400/6471], Loss: 2.1387, Perplexity: 8.48850
# Epoch [3/3], Step [3500/6471], Loss: 1.7458, Perplexity: 5.73034
# Epoch [3/3], Step [3600/6471], Loss: 2.0663, Perplexity: 7.89570
# Epoch [3/3], Step [3700/6471], Loss: 1.9606, Perplexity: 7.10365
# Epoch [3/3], Step [3800/6471], Loss: 2.0258, Perplexity: 7.58186
# Epoch [3/3], Step [3900/6471], Loss: 1.9850, Perplexity: 7.27921
# Epoch [3/3], Step [4000/6471], Loss: 2.9137, Perplexity: 18.4257
# Epoch [3/3], Step [4100/6471], Loss: 2.6856, Perplexity: 14.6669
# Epoch [3/3], Step [4200/6471], Loss: 1.8593, Perplexity: 6.41943
# Epoch [3/3], Step [4300/6471], Loss: 2.0242, Perplexity: 7.57008
# Epoch [3/3], Step [4400/6471], Loss: 1.9245, Perplexity: 6.85175
# Epoch [3/3], Step [4500/6471], Loss: 1.8670, Perplexity: 6.46893
# Epoch [3/3], Step [4600/6471], Loss: 2.3416, Perplexity: 10.3981
# Epoch [3/3], Step [4700/6471], Loss: 2.5986, Perplexity: 13.4446
# Epoch [3/3], Step [4800/6471], Loss: 2.5709, Perplexity: 13.0776
# Epoch [3/3], Step [4900/6471], Loss: 1.7565, Perplexity: 5.79191
# Epoch [3/3], Step [5000/6471], Loss: 2.4732, Perplexity: 11.8599
# Epoch [3/3], Step [5100/6471], Loss: 2.5356, Perplexity: 12.6239
# Epoch [3/3], Step [5200/6471], Loss: 1.7911, Perplexity: 5.99617
# Epoch [3/3], Step [5300/6471], Loss: 2.1107, Perplexity: 8.25441
# Epoch [3/3], Step [5400/6471], Loss: 2.2044, Perplexity: 9.06517
# Epoch [3/3], Step [5500/6471], Loss: 1.9791, Perplexity: 7.23612
# Epoch [3/3], Step [5600/6471], Loss: 1.8886, Perplexity: 6.61037
# Epoch [3/3], Step [5700/6471], Loss: 2.2514, Perplexity: 9.50109
# Epoch [3/3], Step [5800/6471], Loss: 2.1643, Perplexity: 8.70837
# Epoch [3/3], Step [5900/6471], Loss: 2.0794, Perplexity: 8.00009
# Epoch [3/3], Step [6000/6471], Loss: 1.9909, Perplexity: 7.32231
# Epoch [3/3], Step [6100/6471], Loss: 2.2177, Perplexity: 9.18652
# Epoch [3/3], Step [6200/6471], Loss: 2.0302, Perplexity: 7.61588
# Epoch [3/3], Step [6300/6471], Loss: 1.9760, Perplexity: 7.21352
# Epoch [3/3], Step [6400/6471], Loss: 1.9210, Perplexity: 6.82781
# Epoch [3/3], Step [6471/6471], Loss: 2.3752, Perplexity: 10.7534

# %% [markdown]
# <a id='step3'></a>
# ## Step 3: (Optional) Validate your Model
#
# To assess potential overfitting, one approach is to assess performance on a validation set.  If you decide to do this **optional** task, you are required to first complete all of the steps in the next notebook in the sequence (**3_Inference.ipynb**); as part of that notebook, you will write and test code (specifically, the `sample` method in the `DecoderRNN` class) that uses your RNN decoder to generate captions.  That code will prove incredibly useful here.
#
# If you decide to validate your model, please do not edit the data loader in **data_loader.py**.  Instead, create a new file named **data_loader_val.py** containing the code for obtaining the data loader for the validation data.  You can access:
# - the validation images at filepath `'/opt/cocoapi/images/train2014/'`, and
# - the validation image caption annotation file at filepath `'/opt/cocoapi/annotations/captions_val2014.json'`.
#
# The suggested approach to validating your model involves creating a json file such as [this one](https://github.com/cocodataset/cocoapi/blob/master/results/captions_val2014_fakecap_results.json) containing your model's predicted captions for the validation images.  Then, you can write your own script or use one that you [find online](https://github.com/tylin/coco-caption) to calculate the BLEU score of your model.  You can read more about the BLEU score, along with other evaluation metrics (such as TEOR and Cider) in section 4.1 of [this paper](https://arxiv.org/pdf/1411.4555.pdf).  For more information about how to use the annotation file, check out the [website](http://cocodataset.org/#download) for the COCO dataset.

# %%
# (Optional) TODO: Validate your model.
